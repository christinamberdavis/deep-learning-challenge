# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from tensorflow import keras

#Connect to Google Drive to access data resource and export files
from google.colab import drive, files
drive.mount('/content/drive')

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("/content/drive/MyDrive/CoLabs/deep-learning-challenge/Resources/charity_data.csv")
application_df.head()

#Target: IS_SUCCESSFUL
#Features: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(columns=['EIN', 'NAME'], inplace=True)
application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1              0                      N      5000
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#cutoff value = 500
application_types_to_replace = []
for value in application_df['APPLICATION_TYPE']: 
  if value in application_types_to_replace:
    continue
  elif application_df['APPLICATION_TYPE'].value_counts()[value] < 500:
    application_types_to_replace.append(value)

#print(f"Application types to replace: {application_types_to_replace}")

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
#create a variables out of the value counts
classification_value_counts = application_df['CLASSIFICATION'].value_counts()
#filter that variable for values with counts >1 and store as new variable
classification_value_counts_gt1 = classification_value_counts[classification_value_counts>1]
#print new variable
classification_value_counts_gt1
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#cutoff value = 1800
classifications_to_replace = []
for value in application_df['CLASSIFICATION']: 
  if value in classifications_to_replace:
    continue
  elif application_df['CLASSIFICATION'].value_counts()[value] < 1800:
    classifications_to_replace.append(value)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`

# non-numeric columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
#create a dataframe with dummy data
dummies_df = pd.get_dummies(data=application_df, columns=['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE', 'ORGANIZATION', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS', 'ASK_AMT'])
dummies_df
# Out:
#        STATUS  IS_SUCCESSFUL  APPLICATION_TYPE_Other  APPLICATION_TYPE_T10  \
# 0           1              1                       0                     1
# 1           1              1                       0                     0
# 2           1              0                       0                     0
# 3           1              1                       0                     0
# 4           1              1                       0                     0
# ...       ...            ...                     ...                   ...
# 34294       1              0                       0                     0
# 34295       1              0                       0                     0
# 34296       1              0                       0                     0
# 34297       1              1                       0                     0
# 34298       1              0                       0                     0
#
#        APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  \
# 0                         0                    0                    0
# 1                         0                    1                    0
# 2                         0                    0                    0
# 3                         0                    1                    0
# 4                         0                    1                    0
# ...                     ...                  ...                  ...
# 34294                     0                    0                    1
# 34295                     0                    0                    1
# 34296                     0                    1                    0
# 34297                     0                    0                    0
# 34298                     0                    1                    0
#
#        APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  ...  \
# 0                        0                    0                    0  ...
# 1                        0                    0                    0  ...
# 2                        1                    0                    0  ...
# 3                        0                    0                    0  ...
# 4                        0                    0                    0  ...
# ...                    ...                  ...                  ...  ...
# 34294                    0                    0                    0  ...
# 34295                    0                    0                    0  ...
# 34296                    0                    0                    0  ...
# 34297                    1                    0                    0  ...
# 34298                    0                    0                    0  ...
#
#        ASK_AMT_1665460552  ASK_AMT_1736232349  ASK_AMT_1893400128  \
# 0                       0                   0                   0
# 1                       0                   0                   0
# 2                       0                   0                   0
# 3                       0                   0                   0
# 4                       0                   0                   0
# ...                   ...                 ...                 ...
# 34294                   0                   0                   0
# 34295                   0                   0                   0
# 34296                   0                   0                   0
# 34297                   0                   0                   0
# 34298                   0                   0                   0
#
#        ASK_AMT_2264109450  ASK_AMT_2310256039  ASK_AMT_3391919220  \
# 0                       0                   0                   0
# 1                       0                   0                   0
# 2                       0                   0                   0
# 3                       0                   0                   0
# 4                       0                   0                   0
# ...                   ...                 ...                 ...
# 34294                   0                   0                   0
# 34295                   0                   0                   0
# 34296                   0                   0                   0
# 34297                   0                   0                   0
# 34298                   0                   0                   0
#
#        ASK_AMT_4653011914  ASK_AMT_5591584994  ASK_AMT_8556638692  \
# 0                       0                   0                   0
# 1                       0                   0                   0
# 2                       0                   0                   0
# 3                       0                   0                   0
# 4                       0                   0                   0
# ...                   ...                 ...                 ...
# 34294                   0                   0                   0
# 34295                   0                   0                   0
# 34296                   0                   0                   0
# 34297                   0                   0                   0
# 34298                   0                   0                   0
#
#        ASK_AMT_8597806340
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0
# ...                   ...
# 34294                   0
# 34295                   0
# 34296                   0
# 34297                   0
# 34298                   0
#
# [34299 rows x 8790 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = dummies_df['IS_SUCCESSFUL'].values
X = dummies_df.drop(['IS_SUCCESSFUL', 'STATUS'],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
# Out:
# <ipython-input-10-25348763c58d>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = dummies_df.drop(['IS_SUCCESSFUL', 'STATUS'],1).values

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  80
hidden_nodes_layer2 = 30
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)
# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                703120
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 705,581
# Trainable params: 705,581
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
my_callbacks = keras.callbacks.ModelCheckpoint(filepath='/content/drive/MyDrive/CoLabs/deep-learning-challenge/Deep Learning Challenge/Output/saved_model_weights.h5', save_weights_only=True, save_freq=5)

# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100, callbacks=[my_callbacks])
# Out:
# Epoch 1/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3918 - accuracy: 0.8126
# Epoch 2/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.3917 - accuracy: 0.8126
# Epoch 3/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.3916 - accuracy: 0.8131
# Epoch 4/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3916 - accuracy: 0.8141
# Epoch 5/100
# 804/804 [==============================] - 13s 16ms/step - loss: 0.3907 - accuracy: 0.8143
# Epoch 6/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3916 - accuracy: 0.8145
# Epoch 7/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3911 - accuracy: 0.8139
# Epoch 8/100
# 804/804 [==============================] - 13s 17ms/step - loss: 0.3906 - accuracy: 0.8145
# Epoch 9/100
# 804/804 [==============================] - 13s 17ms/step - loss: 0.3898 - accuracy: 0.8150
# Epoch 10/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3909 - accuracy: 0.8146
# Epoch 11/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3905 - accuracy: 0.8144
# Epoch 12/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3899 - accuracy: 0.8144
# Epoch 13/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3902 - accuracy: 0.8138
# Epoch 14/100
# 804/804 [==============================] - 12s 16ms/step - loss: 0.3897 - accuracy: 0.8138
# Epoch 15/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3897 - accuracy: 0.8145
# Epoch 16/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3897 - accuracy: 0.8144
# Epoch 17/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3894 - accuracy: 0.8140
# Epoch 18/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3892 - accuracy: 0.8139
# Epoch 19/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3893 - accuracy: 0.8152
# Epoch 20/100
# 804/804 [==============================] - 13s 16ms/step - loss: 0.3889 - accuracy: 0.8143
# Epoch 21/100
# 804/804 [==============================] - 13s 16ms/step - loss: 0.3887 - accuracy: 0.8145
# Epoch 22/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3898 - accuracy: 0.8147
# Epoch 23/100
# 804/804 [==============================] - 14s 18ms/step - loss: 0.3890 - accuracy: 0.8146
# Epoch 24/100
# 804/804 [==============================] - 13s 16ms/step - loss: 0.3890 - accuracy: 0.8144
# Epoch 25/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3886 - accuracy: 0.8147
# Epoch 26/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3889 - accuracy: 0.8145
# Epoch 27/100
# 804/804 [==============================] - 12s 14ms/step - loss: 0.3887 - accuracy: 0.8151
# Epoch 28/100
# 804/804 [==============================] - 12s 14ms/step - loss: 0.3885 - accuracy: 0.8148
# Epoch 29/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3883 - accuracy: 0.8156
# Epoch 30/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3884 - accuracy: 0.8147
# Epoch 31/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3884 - accuracy: 0.8145
# Epoch 32/100
# 804/804 [==============================] - 13s 16ms/step - loss: 0.3877 - accuracy: 0.8150
# Epoch 33/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3876 - accuracy: 0.8152
# Epoch 34/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3880 - accuracy: 0.8161
# Epoch 35/100
# 804/804 [==============================] - 13s 16ms/step - loss: 0.3877 - accuracy: 0.8146
# Epoch 36/100
# 804/804 [==============================] - 13s 16ms/step - loss: 0.3880 - accuracy: 0.8159
# Epoch 37/100
# 804/804 [==============================] - 13s 16ms/step - loss: 0.3873 - accuracy: 0.8160
# Epoch 38/100
# 804/804 [==============================] - 13s 16ms/step - loss: 0.3874 - accuracy: 0.8162
# Epoch 39/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3875 - accuracy: 0.8150
# Epoch 40/100
# 804/804 [==============================] - 13s 16ms/step - loss: 0.3874 - accuracy: 0.8145
# Epoch 41/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3872 - accuracy: 0.8156
# Epoch 42/100
# 804/804 [==============================] - 13s 16ms/step - loss: 0.3875 - accuracy: 0.8146
# Epoch 43/100
# 804/804 [==============================] - 13s 17ms/step - loss: 0.3873 - accuracy: 0.8155
# Epoch 44/100
# 804/804 [==============================] - 13s 16ms/step - loss: 0.3868 - accuracy: 0.8152
# Epoch 45/100
# 804/804 [==============================] - 13s 16ms/step - loss: 0.3868 - accuracy: 0.8159
# Epoch 46/100
# 804/804 [==============================] - 13s 16ms/step - loss: 0.3868 - accuracy: 0.8164
# Epoch 47/100
# 804/804 [==============================] - 13s 16ms/step - loss: 0.3868 - accuracy: 0.8159
# Epoch 48/100
# 804/804 [==============================] - 13s 16ms/step - loss: 0.3870 - accuracy: 0.8155
# Epoch 49/100
# 804/804 [==============================] - 13s 16ms/step - loss: 0.3868 - accuracy: 0.8155
# Epoch 50/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3870 - accuracy: 0.8158
# Epoch 51/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3869 - accuracy: 0.8160
# Epoch 52/100
# 804/804 [==============================] - 13s 16ms/step - loss: 0.3864 - accuracy: 0.8167
# Epoch 53/100
# 804/804 [==============================] - 15s 19ms/step - loss: 0.3865 - accuracy: 0.8155
# Epoch 54/100
# 804/804 [==============================] - 13s 16ms/step - loss: 0.3864 - accuracy: 0.8161
# Epoch 55/100
# 804/804 [==============================] - 14s 17ms/step - loss: 0.3873 - accuracy: 0.8152
# Epoch 56/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3864 - accuracy: 0.8164
# Epoch 57/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3863 - accuracy: 0.8164
# Epoch 58/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3868 - accuracy: 0.8161
# Epoch 59/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3862 - accuracy: 0.8157
# Epoch 60/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3872 - accuracy: 0.8160
# Epoch 61/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3865 - accuracy: 0.8166
# Epoch 62/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3869 - accuracy: 0.8160
# Epoch 63/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3861 - accuracy: 0.8165
# Epoch 64/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3861 - accuracy: 0.8160
# Epoch 65/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3865 - accuracy: 0.8165
# Epoch 66/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3861 - accuracy: 0.8160
# Epoch 67/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3861 - accuracy: 0.8167
# Epoch 68/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3862 - accuracy: 0.8160
# Epoch 69/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3863 - accuracy: 0.8164
# Epoch 70/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3867 - accuracy: 0.8165
# Epoch 71/100
# 804/804 [==============================] - 13s 16ms/step - loss: 0.3873 - accuracy: 0.8160
# Epoch 72/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3860 - accuracy: 0.8164
# Epoch 73/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3866 - accuracy: 0.8162
# Epoch 74/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3871 - accuracy: 0.8160
# Epoch 75/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3868 - accuracy: 0.8162
# Epoch 76/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3859 - accuracy: 0.8167
# Epoch 77/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3856 - accuracy: 0.8165
# Epoch 78/100
# 804/804 [==============================] - 13s 16ms/step - loss: 0.3860 - accuracy: 0.8158
# Epoch 79/100
# 804/804 [==============================] - 12s 14ms/step - loss: 0.3855 - accuracy: 0.8163
# Epoch 80/100
# 804/804 [==============================] - 12s 14ms/step - loss: 0.3857 - accuracy: 0.8162
# Epoch 81/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3856 - accuracy: 0.8166
# Epoch 82/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3856 - accuracy: 0.8158
# Epoch 83/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3858 - accuracy: 0.8160
# Epoch 84/100
# 804/804 [==============================] - 12s 14ms/step - loss: 0.3855 - accuracy: 0.8166
# Epoch 85/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.3857 - accuracy: 0.8163
# Epoch 86/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3856 - accuracy: 0.8158
# Epoch 87/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3852 - accuracy: 0.8166
# Epoch 88/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3853 - accuracy: 0.8166
# Epoch 89/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3856 - accuracy: 0.8165
# Epoch 90/100
# 804/804 [==============================] - 13s 16ms/step - loss: 0.3858 - accuracy: 0.8169
# Epoch 91/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3866 - accuracy: 0.8153
# Epoch 92/100
# 804/804 [==============================] - 14s 17ms/step - loss: 0.3857 - accuracy: 0.8162
# Epoch 93/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3852 - accuracy: 0.8171
# Epoch 94/100
# 804/804 [==============================] - 12s 16ms/step - loss: 0.3851 - accuracy: 0.8168
# Epoch 95/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3854 - accuracy: 0.8163
# Epoch 96/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.3856 - accuracy: 0.8165
# Epoch 97/100
# 804/804 [==============================] - 12s 14ms/step - loss: 0.3852 - accuracy: 0.8165
# Epoch 98/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3851 - accuracy: 0.8161
# Epoch 99/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.3857 - accuracy: 0.8164
# Epoch 100/100
# 804/804 [==============================] - 12s 14ms/step - loss: 0.3862 - accuracy: 0.8165

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.9266 - accuracy: 0.7150 - 818ms/epoch - 3ms/step
# Loss: 0.9265857338905334, Accuracy: 0.7149854302406311

# %%
# Export our model to HDF5 file
nn.save('/content/drive/MyDrive/CoLabs/deep-learning-challenge/Deep Learning Challenge/Output/AlphabetSoupCharity.h5')
